# %% [markdown]
# # GRU Forecasting Bitcoin Price
#
# ---

# %% [markdown]
# ## 1. Introduction
#
# Historical data of cryptocurrency prices will be used to predict Adjusted Close prices by building a multi-layer Recurrent Neural Network model. The ability to store information over a period of time is useful when dealing with time series data.

# %% [markdown]
# ##2. Import/Install Library

# %%
import yfinance as yf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import seaborn as sns
import math
import datetime
import keras
import warnings
import tensorflow as tf
import random as rn
warnings.filterwarnings('ignore')

from datetime import date, timedelta
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import GRU, LSTM, SimpleRNN
from keras.layers import Dropout
from keras.layers import *
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.feature_selection import SelectKBest, f_regression
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %matplotlib inline

# %% [markdown]
# ## 3. Import data
#
# Read in cryptocurrency data  downloaded from Yahoo! Finance using yfinance API into a pandas DataFrame.

# %%
### Unduh data dengan API Yfinance dan dijadikan DataFrame
#stock_kode = input("Masukkan Simbol Kode Saham : ")
#range_start_historical_data = input("Masukkan rentang awal historical data format: yyyy-mm-dd : ")
#range_end_historical_data = input("Masukkan rentang akhir historical data format: yyyy-mm-dd : ")
#stock_kode_df = yf.download(stock_kode, range_start_historical_data, range_end_historical_data)

# %%
stock_kode = "XRP-USD"##input("Masukkan Simbol Kode Saham : ")
stock_kode_df = yf.download(stock_kode, start = "2018-08-04", end = "2023-08-04")
stock_kode_df.to_csv("data.csv")

df = pd.read_csv("data.csv")
df['Date'] = pd.to_datetime(df['Date'])

print(df['Date'])
print(df['Date'].tail(1))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 0      2018-08-04
# 1      2018-08-05
# 2      2018-08-06
# 3      2018-08-07
# 4      2018-08-08
#           ...
# 1821   2023-07-30
# 1822   2023-07-31
# 1823   2023-08-01
# 1824   2023-08-02
# 1825   2023-08-03
# Name: Date, Length: 1826, dtype: datetime64[ns]
# 1825   2023-08-03
# Name: Date, dtype: datetime64[ns]

# %%
stock_kode_df.tail
# Out:
# <bound method NDFrame.tail of                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2018-08-04  0.441039  0.443058  0.427125  0.428507   0.428507   185678000
# 2018-08-05  0.428580  0.434594  0.427522  0.433638   0.433638   186848000
# 2018-08-06  0.433886  0.435794  0.406680  0.414081   0.414081   242075000
# 2018-08-07  0.413776  0.415917  0.379526  0.381006   0.381006   244448000
# 2018-08-08  0.380875  0.380875  0.326996  0.331944   0.331944   360857000
# ...              ...       ...       ...       ...        ...         ...
# 2023-07-30  0.712723  0.729810  0.693537  0.705136   0.705136  1323282055
# 2023-07-31  0.705110  0.717364  0.692154  0.698521   0.698521  1488758727
# 2023-08-01  0.698503  0.707211  0.683532  0.707211   0.707211  1438067858
# 2023-08-02  0.707087  0.707087  0.680232  0.685195   0.685195  1132335650
# 2023-08-03  0.685180  0.686761  0.658851  0.664135   0.664135  1414576525
#
# [1826 rows x 6 columns]>

# %%
# Plot Adjusted Close price

stock_kode_df['Adj Close'].plot(grid = True)
sns.set(rc={'figure.figsize':(14, 8)})
plt.title(stock_kode + ' Close Price', color = 'black', fontsize = 20)
plt.xlabel('Year', color = 'black', fontsize = 15)
plt.ylabel('Stock price', color = 'black', fontsize = 15);
plt.savefig("plotBTC.png")

# %%
# Create DataFrame for Adjusted Close price
stock_kode_adj = stock_kode_df[['Adj Close']]

# %%
# Print DataFrame
stock_kode_adj
# Out:
#             Adj Close
# Date
# 2018-08-04   0.428507
# 2018-08-05   0.433638
# 2018-08-06   0.414081
# 2018-08-07   0.381006
# 2018-08-08   0.331944
# ...               ...
# 2023-07-30   0.705136
# 2023-07-31   0.698521
# 2023-08-01   0.707211
# 2023-08-02   0.685195
# 2023-08-03   0.664135
#
# [1826 rows x 1 columns]

# %% [markdown]
# ##4. Create Training Data-set

# %%
# Convert DataFrame to numpy array
stock_kode_adj_arr = stock_kode_adj.values

# Find number of rows to train model on (80% of data set)
training_data_len = int(0.8*len(stock_kode_adj))

# Print
training_data_len
# Out:
# 1460

# %%
# Create train data set

train = stock_kode_adj_arr[0:training_data_len, :]

# %%
train
# Out:
# array([[0.428507  ],
#        [0.43363801],
#        [0.41408101],
#        ...,
#        [0.380458  ],
#        [0.379976  ],
#        [0.37202099]])

# %% [markdown]
# ### Normalisasi Data / Feature scaling
#
# Normalisasi data latihan sebelum memasukkan model dengan mengonversi nilai kolom numerik dalam set data menjadi skala umum. Fungsi MinMaxScaler() dari Scikit-Learn akan menyesuaikan skala data menjadi nilai antara 0 dan 1 yang membantu meningkatkan performa.

# %%
# Normalise the data
scaler = MinMaxScaler(feature_range=(0,1))
train_scaled = scaler.fit_transform(train)

# %%
# Print Normalized Data
print(train_scaled)
# Out:
# [[0.1699646 ]
#  [0.17298354]
#  [0.16147673]
#  ...
#  [0.14169384]
#  [0.14141025]
#  [0.13672973]]

# %%
train_scaled.shape
# Out:
# (1460, 1)

# %% [markdown]
# ### Split training data into X_train, y_train

# %% [markdown]
# Kode berikut merupakan implementasi dari pembuatan data struktur untuk data time series dalam bentuk supervised learning. Data time series diubah menjadi data supervised learning dengan membuat data input (X) dan data output (y) dari data time series yang diberikan.
#
# Kode tersebut melakukan hal berikut:
#
# Membuat dua variabel kosong X_train dan y_train sebagai list untuk menampung data input dan output.
# Melakukan iterasi untuk setiap time-step pada data latihan (train_scaled) dimulai dari time-step ke-60 hingga akhir data.
# Pada setiap iterasi, dilakukan penambahan data input dan output ke dalam list X_train dan y_train. Data input (X_train) berupa 60 time-step sebelum time-step saat ini (i-60) dan data output (y_train) adalah time-step saat ini (i) pada kolom pertama (0) pada data latihan (train_scaled).
# Jika i <= 61, maka akan menampilkan data input dan output pada iterasi tersebut untuk memastikan data terbentuk dengan benar. Hal ini digunakan untuk debugging dan tidak diperlukan pada saat eksekusi sebenarnya.
# Dengan menggunakan kode tersebut, data time series dapat diubah menjadi data supervised learning yang dapat digunakan untuk melatih model machine learning untuk melakukan prediksi.

# %%
# Creating a data structure with 60 time-steps and 1 output

# Split data into X_train and y_train data sets
X_train = []
y_train = []
# Creating a data structure with 60 time-steps and 1 output
for i in range(60, len(train_scaled)):
    X_train.append(train_scaled[i-60:i, 0])
    y_train.append(train_scaled[i:i+1, 0])
    if i <= 61:     # 60 days for first pass, 61 for second
      print(X_train)
      print(y_train)
      print()
# Out:
# [array([0.1699646 , 0.17298354, 0.16147673, 0.14201627, 0.11314949,
#        0.12187331, 0.10637261, 0.09509702, 0.09310127, 0.08109609,
#        0.07921683, 0.08376673, 0.08990405, 0.13358488, 0.11029942,
#        0.12022998, 0.10570011, 0.11505171, 0.10600606, 0.11065773,
#        0.11059713, 0.11096428, 0.10834367, 0.11606725, 0.12485402,
#        0.12071539, 0.11520881, 0.11514291, 0.12243227, 0.11937391,
#        0.115513  , 0.11297768, 0.08470576, 0.09594899, 0.08931508,
#        0.08219458, 0.08181038, 0.07689217, 0.07300242, 0.07675449,
#        0.08293005, 0.08091547, 0.08376848, 0.08327307, 0.07802773,
#        0.10721633, 0.10968339, 0.18256226, 0.24819177, 0.25368482,
#        0.25362071, 0.20891785, 0.22788054, 0.22162437, 0.23637665,
#        0.23504162, 0.25393785, 0.26002397, 0.2570168 , 0.22428912])]
# [array([0.22859895])]
#
# [array([0.1699646 , 0.17298354, 0.16147673, 0.14201627, 0.11314949,
#        0.12187331, 0.10637261, 0.09509702, 0.09310127, 0.08109609,
#        0.07921683, 0.08376673, 0.08990405, 0.13358488, 0.11029942,
#        0.12022998, 0.10570011, 0.11505171, 0.10600606, 0.11065773,
#        0.11059713, 0.11096428, 0.10834367, 0.11606725, 0.12485402,
#        0.12071539, 0.11520881, 0.11514291, 0.12243227, 0.11937391,
#        0.115513  , 0.11297768, 0.08470576, 0.09594899, 0.08931508,
#        0.08219458, 0.08181038, 0.07689217, 0.07300242, 0.07675449,
#        0.08293005, 0.08091547, 0.08376848, 0.08327307, 0.07802773,
#        0.10721633, 0.10968339, 0.18256226, 0.24819177, 0.25368482,
#        0.25362071, 0.20891785, 0.22788054, 0.22162437, 0.23637665,
#        0.23504162, 0.25393785, 0.26002397, 0.2570168 , 0.22428912]), array([0.17298354, 0.16147673, 0.14201627, 0.11314949, 0.12187331,
#        0.10637261, 0.09509702, 0.09310127, 0.08109609, 0.07921683,
#        0.08376673, 0.08990405, 0.13358488, 0.11029942, 0.12022998,
#        0.10570011, 0.11505171, 0.10600606, 0.11065773, 0.11059713,
#        0.11096428, 0.10834367, 0.11606725, 0.12485402, 0.12071539,
#        0.11520881, 0.11514291, 0.12243227, 0.11937391, 0.115513  ,
#        0.11297768, 0.08470576, 0.09594899, 0.08931508, 0.08219458,
#        0.08181038, 0.07689217, 0.07300242, 0.07675449, 0.08293005,
#        0.08091547, 0.08376848, 0.08327307, 0.07802773, 0.10721633,
#        0.10968339, 0.18256226, 0.24819177, 0.25368482, 0.25362071,
#        0.20891785, 0.22788054, 0.22162437, 0.23637665, 0.23504162,
#        0.25393785, 0.26002397, 0.2570168 , 0.22428912, 0.22859895])]
# [array([0.22859895]), array([0.22768345])]

# %%
# Convert X_train and y_train to numpy arrays for training GRU model
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshape the data as GRU expects 3-D data (samples, time steps, features)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (1400, 60, 1)

# %% [markdown]
# ##5. Create test set

# %%
# Create Data Test
test = stock_kode_adj_arr[training_data_len: , :]

# %%
print(test.shape)
# Out:
# (366, 1)

# %%
print(test)
# Out:
# [[0.36985201]
#  [0.371351  ]
#  [0.37659499]
#  [0.371571  ]
#  [0.37250599]
#  [0.37875399]
#  [0.368101  ]
#  [0.38106501]
#  [0.38056299]
#  [0.37999499]
#  [0.37796399]
#  [0.37645099]
#  [0.375774  ]
#  [0.37723699]
#  [0.37970701]
#  [0.370965  ]
#  [0.335049  ]
#  [0.33754101]
#  [0.34530199]
#  [0.34472099]
#  [0.347092  ]
#  [0.346145  ]
#  [0.34949699]
#  [0.33837   ]
#  [0.335347  ]
#  [0.32309499]
#  [0.33379701]
#  [0.32686901]
#  [0.32787001]
#  [0.33319399]
#  [0.33125901]
#  [0.32996899]
#  [0.331799  ]
#  [0.33296001]
#  [0.32220799]
#  [0.337367  ]
#  [0.34024501]
#  [0.357517  ]
#  [0.35768101]
#  [0.35511899]
#  [0.35944501]
#  [0.33369201]
#  [0.34208199]
#  [0.32633501]
#  [0.35668799]
#  [0.377004  ]
#  [0.35832301]
#  [0.38707301]
#  [0.41518301]
#  [0.396828  ]
#  [0.48510101]
#  [0.50717098]
#  [0.48871601]
#  [0.49262699]
#  [0.46767801]
#  [0.44877601]
#  [0.450672  ]
#  [0.48541701]
#  [0.479774  ]
#  [0.47510999]
#  [0.44885001]
#  [0.462879  ]
#  [0.48017401]
#  [0.489683  ]
#  [0.493184  ]
#  [0.518278  ]
#  [0.51711297]
#  [0.53406101]
#  [0.49701399]
#  [0.48539701]
#  [0.48837   ]
#  [0.48081201]
#  [0.48896599]
#  [0.481507  ]
#  [0.47701001]
#  [0.479918  ]
#  [0.46597701]
#  [0.45122701]
#  [0.448084  ]
#  [0.46109799]
#  [0.46546999]
#  [0.469033  ]
#  [0.453821  ]
#  [0.46154401]
#  [0.469376  ]
#  [0.46240699]
#  [0.47398099]
#  [0.47041601]
#  [0.458455  ]
#  [0.46591499]
#  [0.46457699]
#  [0.450874  ]
#  [0.45513499]
#  [0.50440401]
#  [0.49333   ]
#  [0.47067001]
#  [0.465857  ]
#  [0.40624201]
#  [0.33318099]
#  [0.39570501]
#  [0.384159  ]
#  [0.363677  ]
#  [0.340296  ]
#  [0.37640601]
#  [0.38852099]
#  [0.37630099]
#  [0.38254401]
#  [0.38306299]
#  [0.38469899]
#  [0.361945  ]
#  [0.36479899]
#  [0.37606099]
#  [0.38158101]
#  [0.40199199]
#  [0.40841201]
#  [0.39662901]
#  [0.39682099]
#  [0.39031801]
#  [0.39854899]
#  [0.40874299]
#  [0.39670801]
#  [0.39627299]
#  [0.388147  ]
#  [0.390735  ]
#  [0.389584  ]
#  [0.39209399]
#  [0.38372099]
#  [0.39454499]
#  [0.389153  ]
#  [0.38669801]
#  [0.381749  ]
#  [0.38739401]
#  [0.39510199]
#  [0.38641399]
#  [0.37823701]
#  [0.35198799]
#  [0.35481   ]
#  [0.35027   ]
#  [0.33886999]
#  [0.34937301]
#  [0.34602001]
#  [0.34959999]
#  [0.35427299]
#  [0.35217899]
#  [0.34639201]
#  [0.36572301]
#  [0.368126  ]
#  [0.35653099]
#  [0.34284601]
#  [0.34501699]
#  [0.33992901]
#  [0.338763  ]
#  [0.34855601]
#  [0.343824  ]
#  [0.347794  ]
#  [0.33803901]
#  [0.34464499]
#  [0.34426799]
#  [0.34535801]
#  [0.34933999]
#  [0.35124099]
#  [0.37415799]
#  [0.37519699]
#  [0.385804  ]
#  [0.39544299]
#  [0.38488099]
#  [0.386576  ]
#  [0.38771099]
#  [0.37945199]
#  [0.393785  ]
#  [0.413344  ]
#  [0.40353301]
#  [0.400967  ]
#  [0.424943  ]
#  [0.40770701]
#  [0.41769299]
#  [0.41010299]
#  [0.41279101]
#  [0.40813401]
#  [0.413764  ]
#  [0.394591  ]
#  [0.406389  ]
#  [0.413892  ]
#  [0.409747  ]
#  [0.41220501]
#  [0.41130501]
#  [0.39893699]
#  [0.39282399]
#  [0.40390399]
#  [0.39805201]
#  [0.38246599]
#  [0.38264501]
#  [0.38400799]
#  [0.37528199]
#  [0.37167501]
#  [0.38240701]
#  [0.40135199]
#  [0.38515699]
#  [0.395302  ]
#  [0.39463001]
#  [0.38631701]
#  [0.398525  ]
#  [0.39190501]
#  [0.39558601]
#  [0.38913   ]
#  [0.37847701]
#  [0.37808499]
#  [0.378041  ]
#  [0.37911499]
#  [0.37715   ]
#  [0.38387901]
#  [0.37757999]
#  [0.377671  ]
#  [0.373813  ]
#  [0.367194  ]
#  [0.370471  ]
#  [0.380548  ]
#  [0.38918799]
#  [0.37213001]
#  [0.37062201]
#  [0.36683199]
#  [0.37331799]
#  [0.373786  ]
#  [0.37427899]
#  [0.360558  ]
#  [0.366025  ]
#  [0.380382  ]
#  [0.37443301]
#  [0.38846499]
#  [0.37462801]
#  [0.46970999]
#  [0.42247999]
#  [0.44485   ]
#  [0.42590201]
#  [0.44471601]
#  [0.44881701]
#  [0.47999099]
#  [0.51505798]
#  [0.54357702]
#  [0.53424901]
#  [0.53849202]
#  [0.514741  ]
#  [0.51895303]
#  [0.49696001]
#  [0.503479  ]
#  [0.506235  ]
#  [0.50329798]
#  [0.51373601]
#  [0.50571603]
#  [0.50583398]
#  [0.518318  ]
#  [0.51751798]
#  [0.50611502]
#  [0.51329201]
#  [0.52399302]
#  [0.52044398]
#  [0.52139199]
#  [0.511127  ]
#  [0.53226399]
#  [0.49159899]
#  [0.47485799]
#  [0.44939601]
#  [0.47266099]
#  [0.46501601]
#  [0.46127301]
#  [0.46999499]
#  [0.462037  ]
#  [0.46686801]
#  [0.48027101]
#  [0.47840899]
#  [0.472332  ]
#  [0.464966  ]
#  [0.46495101]
#  [0.463494  ]
#  [0.461573  ]
#  [0.46779999]
#  [0.45954901]
#  [0.45036399]
#  [0.42891499]
#  [0.42988801]
#  [0.43087301]
#  [0.42187899]
#  [0.430718  ]
#  [0.42490301]
#  [0.42585999]
#  [0.427562  ]
#  [0.44142199]
#  [0.448589  ]
#  [0.46029899]
#  [0.46798199]
#  [0.46908101]
#  [0.45754999]
#  [0.46160099]
#  [0.46542999]
#  [0.45360899]
#  [0.45373401]
#  [0.46913999]
#  [0.47224501]
#  [0.482889  ]
#  [0.494151  ]
#  [0.52193803]
#  [0.51738602]
#  [0.50731701]
#  [0.52538699]
#  [0.51935101]
#  [0.53591102]
#  [0.51039398]
#  [0.53046399]
#  [0.51962799]
#  [0.52454603]
#  [0.53791702]
#  [0.50819898]
#  [0.52122098]
#  [0.52572101]
#  [0.52008599]
#  [0.48021999]
#  [0.48011801]
#  [0.475743  ]
#  [0.47979   ]
#  [0.487573  ]
#  [0.493395  ]
#  [0.49287   ]
#  [0.50069499]
#  [0.494975  ]
#  [0.496566  ]
#  [0.487313  ]
#  [0.49027699]
#  [0.479332  ]
#  [0.48383999]
#  [0.465222  ]
#  [0.474722  ]
#  [0.47403699]
#  [0.47352201]
#  [0.48449299]
#  [0.48954701]
#  [0.48784199]
#  [0.47827199]
#  [0.46373901]
#  [0.46876499]
#  [0.470644  ]
#  [0.46855   ]
#  [0.47766399]
#  [0.475719  ]
#  [0.47110501]
#  [0.81536502]
#  [0.71915698]
#  [0.71327901]
#  [0.74686003]
#  [0.739205  ]
#  [0.77954   ]
#  [0.82069403]
#  [0.79405802]
#  [0.77250201]
#  [0.73328698]
#  [0.73868299]
#  [0.70276499]
#  [0.70959997]
#  [0.71579897]
#  [0.71364599]
#  [0.71256799]
#  [0.71273899]
#  [0.705136  ]
#  [0.69852102]
#  [0.70721102]
#  [0.68519503]
#  [0.66413498]]

# %%
# Predicting 253 values, using past 60 from the train data
inputs = stock_kode_adj_arr[len(stock_kode_adj_arr) - len(test) - 60:]
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

# %%
inputs
# Out:
# array([[0.14866666],
#        [0.15047355],
#        [0.15496343],
#        [0.15772349],
#        [0.1535731 ],
#        [0.15338246],
#        [0.14244579],
#        [0.12908324],
#        [0.12111961],
#        [0.10071012],
#        [0.10738284],
#        [0.12006818],
#        [0.10144793],
#        [0.10693451],
#        [0.09911444],
#        [0.10968339],
#        [0.10809066],
#        [0.11119728],
#        [0.1076429 ],
#        [0.11525999],
#        [0.13412089],
#        [0.13410265],
#        [0.12898852],
#        [0.12567656],
#        [0.11631789],
#        [0.11140438],
#        [0.11285766],
#        [0.10240169],
#        [0.10352077],
#        [0.10712396],
#        [0.11129377],
#        [0.10931272],
#        [0.11334248],
#        [0.11915502],
#        [0.1188473 ],
#        [0.12080305],
#        [0.10945393],
#        [0.10276647],
#        [0.10121435],
#        [0.10831659],
#        [0.11390084],
#        [0.11467398],
#        [0.12427977],
#        [0.11989697],
#        [0.13329128],
#        [0.13743814],
#        [0.12994168],
#        [0.13379671],
#        [0.12883554],
#        [0.12938684],
#        [0.1292215 ],
#        [0.11630965],
#        [0.11660443],
#        [0.12913797],
#        [0.13752699],
#        [0.13476104],
#        [0.1459925 ],
#        [0.14169384],
#        [0.14141025],
#        [0.13672973],
#        [0.13545356],
#        [0.13633553],
#        [0.13942095],
#        [0.13646497],
#        [0.1370151 ],
#        [0.14069125],
#        [0.13442332],
#        [0.14205099],
#        [0.14175562],
#        [0.14142142],
#        [0.14022644],
#        [0.13933622],
#        [0.1389379 ],
#        [0.13979869],
#        [0.14125198],
#        [0.13610842],
#        [0.1149764 ],
#        [0.11644263],
#        [0.12100898],
#        [0.12066714],
#        [0.12206218],
#        [0.12150499],
#        [0.12347721],
#        [0.11693038],
#        [0.11515173],
#        [0.10794298],
#        [0.11423976],
#        [0.11016351],
#        [0.11075247],
#        [0.11388496],
#        [0.11274647],
#        [0.11198745],
#        [0.11306418],
#        [0.11374729],
#        [0.10742109],
#        [0.11634025],
#        [0.11803359],
#        [0.12819597],
#        [0.12829247],
#        [0.12678505],
#        [0.12933036],
#        [0.11417798],
#        [0.11911442],
#        [0.10984932],
#        [0.12770821],
#        [0.1396616 ],
#        [0.1286702 ],
#        [0.14558594],
#        [0.16212511],
#        [0.15132551],
#        [0.20326301],
#        [0.21624839],
#        [0.20538997],
#        [0.2076911 ],
#        [0.19301178],
#        [0.18189034],
#        [0.18300589],
#        [0.20344893],
#        [0.20012873],
#        [0.19738456],
#        [0.18193388],
#        [0.19018817],
#        [0.20036409],
#        [0.20595893],
#        [0.20801882],
#        [0.22278347],
#        [0.22209799],
#        [0.23206977],
#        [0.21027228],
#        [0.20343717],
#        [0.20518639],
#        [0.20073947],
#        [0.20553706],
#        [0.20114839],
#        [0.19850248],
#        [0.20021346],
#        [0.19201096],
#        [0.18333245],
#        [0.18148318],
#        [0.18914027],
#        [0.19171263],
#        [0.19380902],
#        [0.18485868],
#        [0.18940269],
#        [0.19401083],
#        [0.18991045],
#        [0.19672028],
#        [0.19462274],
#        [0.1875852 ],
#        [0.19197447],
#        [0.19118722],
#        [0.18312474],
#        [0.1856318 ],
#        [0.21462038],
#        [0.20810473],
#        [0.19477219],
#        [0.19194034],
#        [0.15686447],
#        [0.11387731],
#        [0.15066478],
#        [0.14387141],
#        [0.13182035],
#        [0.11806359],
#        [0.13930976],
#        [0.14643789],
#        [0.13924797],
#        [0.1429212 ],
#        [0.14322655],
#        [0.14418913],
#        [0.13080129],
#        [0.1324805 ],
#        [0.13910676],
#        [0.14235459],
#        [0.15436387],
#        [0.15814124],
#        [0.15120843],
#        [0.15132139],
#        [0.14749521],
#        [0.1523381 ],
#        [0.15833598],
#        [0.15125492],
#        [0.15099896],
#        [0.14621785],
#        [0.14774056],
#        [0.14706334],
#        [0.14854015],
#        [0.1436137 ],
#        [0.14998225],
#        [0.14680975],
#        [0.1453653 ],
#        [0.14245344],
#        [0.14577481],
#        [0.15030998],
#        [0.14519819],
#        [0.14038707],
#        [0.12494285],
#        [0.12660324],
#        [0.12393203],
#        [0.11722457],
#        [0.12340427],
#        [0.12143145],
#        [0.12353781],
#        [0.12628728],
#        [0.12505523],
#        [0.12165032],
#        [0.13302417],
#        [0.13443803],
#        [0.12761583],
#        [0.11956395],
#        [0.1208413 ],
#        [0.11784767],
#        [0.11716162],
#        [0.12292356],
#        [0.12013937],
#        [0.12247521],
#        [0.11673564],
#        [0.12062242],
#        [0.12040061],
#        [0.12104195],
#        [0.12338484],
#        [0.12450334],
#        [0.13798709],
#        [0.13859841],
#        [0.14483929],
#        [0.15051062],
#        [0.14429621],
#        [0.14529351],
#        [0.14596131],
#        [0.14110194],
#        [0.1495351 ],
#        [0.16104309],
#        [0.15527057],
#        [0.1537608 ],
#        [0.16786763],
#        [0.15772643],
#        [0.16360192],
#        [0.15913617],
#        [0.16071773],
#        [0.15797767],
#        [0.16129021],
#        [0.15000933],
#        [0.15695095],
#        [0.16136552],
#        [0.15892672],
#        [0.16037294],
#        [0.1598434 ],
#        [0.15256639],
#        [0.14896967],
#        [0.15548884],
#        [0.15204569],
#        [0.14287529],
#        [0.14298062],
#        [0.14378256],
#        [0.13864842],
#        [0.13652617],
#        [0.14284059],
#        [0.15398731],
#        [0.1444586 ],
#        [0.15042766],
#        [0.15003228],
#        [0.14514113],
#        [0.15232399],
#        [0.14842896],
#        [0.15059477],
#        [0.14679622],
#        [0.14052828],
#        [0.14029763],
#        [0.14027175],
#        [0.14090365],
#        [0.1397475 ],
#        [0.14370667],
#        [0.1400005 ],
#        [0.14005405],
#        [0.13778411],
#        [0.13388966],
#        [0.13581776],
#        [0.1417468 ],
#        [0.14683034],
#        [0.13679387],
#        [0.13590661],
#        [0.13367666],
#        [0.13749285],
#        [0.13776822],
#        [0.13805828],
#        [0.12998522],
#        [0.13320185],
#        [0.14164913],
#        [0.1381489 ],
#        [0.14640494],
#        [0.13826363],
#        [0.19420734],
#        [0.16641846],
#        [0.17958038],
#        [0.16843189],
#        [0.17950155],
#        [0.18191447],
#        [0.20025641],
#        [0.22088889],
#        [0.23766873],
#        [0.23218038],
#        [0.23467686],
#        [0.22070239],
#        [0.22318063],
#        [0.21024053],
#        [0.21407613],
#        [0.21569769],
#        [0.21396962],
#        [0.22011108],
#        [0.21539233],
#        [0.21546174],
#        [0.222807  ],
#        [0.22233629],
#        [0.21562709],
#        [0.21984984],
#        [0.22614603],
#        [0.22405787],
#        [0.22461565],
#        [0.218576  ],
#        [0.23101245],
#        [0.20708625],
#        [0.19723628],
#        [0.18225514],
#        [0.19594363],
#        [0.19144553],
#        [0.18924325],
#        [0.19437503],
#        [0.18969275],
#        [0.1925352 ],
#        [0.20042116],
#        [0.1993256 ],
#        [0.19575006],
#        [0.1914161 ],
#        [0.19140728],
#        [0.19055002],
#        [0.18941975],
#        [0.19308355],
#        [0.18822889],
#        [0.18282467],
#        [0.17020465],
#        [0.17077715],
#        [0.17135669],
#        [0.16606485],
#        [0.17126549],
#        [0.1678441 ],
#        [0.16840717],
#        [0.16940858],
#        [0.17756343],
#        [0.18178031],
#        [0.18867015],
#        [0.19319063],
#        [0.19383727],
#        [0.18705272],
#        [0.18943622],
#        [0.1916891 ],
#        [0.18473394],
#        [0.1848075 ],
#        [0.19387197],
#        [0.19569888],
#        [0.20196152],
#        [0.20858778],
#        [0.22493693],
#        [0.22225865],
#        [0.21633431],
#        [0.2269662 ],
#        [0.22341479],
#        [0.23315827],
#        [0.21814471],
#        [0.22995338],
#        [0.22357776],
#        [0.2264714 ],
#        [0.23433854],
#        [0.21685323],
#        [0.22451504],
#        [0.22716273],
#        [0.22384724],
#        [0.20039114],
#        [0.20033114],
#        [0.197757  ],
#        [0.20013815],
#        [0.20471746],
#        [0.20814297],
#        [0.20783407],
#        [0.21243809],
#        [0.2090726 ],
#        [0.2100087 ],
#        [0.20456448],
#        [0.20630842],
#        [0.19986867],
#        [0.20252105],
#        [0.19156673],
#        [0.19715627],
#        [0.19675323],
#        [0.19645023],
#        [0.20290526],
#        [0.20587892],
#        [0.20487573],
#        [0.19924499],
#        [0.19069417],
#        [0.19365133],
#        [0.19475688],
#        [0.19352483],
#        [0.19888726],
#        [0.19774288],
#        [0.19502813],
#        [0.39758156],
#        [0.34097531],
#        [0.33751687],
#        [0.35727504],
#        [0.35277103],
#        [0.37650307],
#        [0.40071701],
#        [0.38504509],
#        [0.3723621 ],
#        [0.34928902],
#        [0.35246389],
#        [0.3313307 ],
#        [0.33535222],
#        [0.33899955],
#        [0.33773279],
#        [0.33709852],
#        [0.33719913],
#        [0.33272574],
#        [0.32883366],
#        [0.33394662],
#        [0.320993  ],
#        [0.30860183]])

# %%
# Create data sets X_test and y_test
X_test = []
y_test = stock_kode_adj_arr[training_data_len:, :]
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])

# %%
# Convert data to numpy array
X_test = np.array(X_test)

# %%
# Reshape data to be 3-D.
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
print(X_test.shape)
# Out:
# (366, 60, 1)

# %%
X_test
# Out:
# array([[[0.14866666],
#         [0.15047355],
#         [0.15496343],
#         ...,
#         [0.14169384],
#         [0.14141025],
#         [0.13672973]],
#
#        [[0.15047355],
#         [0.15496343],
#         [0.15772349],
#         ...,
#         [0.14141025],
#         [0.13672973],
#         [0.13545356]],
#
#        [[0.15496343],
#         [0.15772349],
#         [0.1535731 ],
#         ...,
#         [0.13672973],
#         [0.13545356],
#         [0.13633553]],
#
#        ...,
#
#        [[0.2269662 ],
#         [0.22341479],
#         [0.23315827],
#         ...,
#         [0.33719913],
#         [0.33272574],
#         [0.32883366]],
#
#        [[0.22341479],
#         [0.23315827],
#         [0.21814471],
#         ...,
#         [0.33272574],
#         [0.32883366],
#         [0.33394662]],
#
#        [[0.23315827],
#         [0.21814471],
#         [0.22995338],
#         ...,
#         [0.32883366],
#         [0.33394662],
#         [0.320993  ]]])

# %% [markdown]
# ##6. Creating Model and Train

# %% [markdown]
# ###Define Hyperparameter Untuk Model

# %%
# Define hyperparameters
learning_rate = 0.0001
num_neurons = 100
dropout_rate = 0.2
num_epochs = 200
batch_size = 64

# %% [markdown]
# ###Model GRU

# %%
# Set random seed for consistency of training
np.random.seed(8)
rn.seed(8)
tf.random.set_seed(8)

# Build model - GRU with 100 neurons and 5 hidden layers
model_gru = Sequential()
model_gru.add(GRU(units = num_neurons, return_sequences = True, input_shape = (X_train.shape[1], 1), activation='tanh'))
model_gru.add(Dropout(dropout_rate))
model_gru.add(GRU(units = num_neurons, return_sequences = True, activation='tanh'))
model_gru.add(Dropout(dropout_rate))
model_gru.add(GRU(units = num_neurons, return_sequences = True, activation='tanh'))
model_gru.add(Dropout(dropout_rate))
model_gru.add(GRU(units = num_neurons, activation='tanh'))
model_gru.add(Dropout(dropout_rate))

# Adding the output layer
model_gru.add(Dense(units = 1))

# Compiling the RNN with Adam optimizer and mean squared error as the loss function
opt = keras.optimizers.Adam(learning_rate)
model_gru.compile(optimizer = opt, loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model_gru.fit(X_train, y_train, epochs = num_epochs, batch_size = batch_size)
# Out:
# Epoch 1/200
# 22/22 [==============================] - 17s 26ms/step - loss: 0.0518
# Epoch 2/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0131
# Epoch 3/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0064
# Epoch 4/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0036
# Epoch 5/200
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0036
# Epoch 6/200
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0037
# Epoch 7/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0035
# Epoch 8/200
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0033
# Epoch 9/200
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0032
# Epoch 10/200
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0034
# Epoch 11/200
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0031
# Epoch 12/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0030
# Epoch 13/200
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0032
# Epoch 14/200
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0031
# Epoch 15/200
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0029
# Epoch 16/200
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0029
# Epoch 17/200
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0030
# Epoch 18/200
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0031
# Epoch 19/200
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0029
# Epoch 20/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0027
# Epoch 21/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0024
# Epoch 22/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0026
# Epoch 23/200
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0027
# Epoch 24/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0024
# Epoch 25/200
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0025
# Epoch 26/200
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0023
# Epoch 27/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 28/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 29/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 30/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0024
# Epoch 31/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 32/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0021
# Epoch 33/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 34/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 35/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0021
# Epoch 36/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 37/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 38/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0019
# Epoch 39/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 40/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 41/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0020
# Epoch 42/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0020
# Epoch 43/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 44/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0019
# Epoch 45/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0018
# Epoch 46/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0018
# Epoch 47/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0017
# Epoch 48/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0017
# Epoch 49/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019
# Epoch 50/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 51/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 52/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 53/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0017
# Epoch 54/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 55/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 56/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0017
# Epoch 57/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0016
# Epoch 58/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 59/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 60/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0018
# Epoch 61/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0016
# Epoch 62/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018
# Epoch 63/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0016
# Epoch 64/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0014
# Epoch 65/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0016
# Epoch 66/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0015
# Epoch 67/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 68/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0015
# Epoch 69/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0015
# Epoch 70/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 71/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0015
# Epoch 72/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0015
# Epoch 73/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 74/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0017
# Epoch 75/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0016
# Epoch 76/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0015
# Epoch 77/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 78/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 79/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0017
# Epoch 80/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 81/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0015
# Epoch 82/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0014
# Epoch 83/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0015
# Epoch 84/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0015
# Epoch 85/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0014
# Epoch 86/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0014
# Epoch 87/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0015
# Epoch 88/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 89/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 90/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 91/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 92/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 93/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 94/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 95/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 96/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 97/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 98/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0015
# Epoch 99/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 100/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 101/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 102/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 103/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 104/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 105/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 106/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 107/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 108/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 109/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 110/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 111/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 112/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 113/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 114/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0013
# Epoch 115/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0014
# Epoch 116/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 117/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 118/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 119/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0014
# Epoch 120/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0014
# Epoch 121/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0013
# Epoch 122/200
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0012
# Epoch 123/200
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0012
# Epoch 124/200
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0011
# Epoch 125/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0011
# Epoch 126/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0012
# Epoch 127/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0012
# Epoch 128/200
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0011
# Epoch 129/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0012
# Epoch 130/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0011
# Epoch 131/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0012
# Epoch 132/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0011
# Epoch 133/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0012
# Epoch 134/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0013
# Epoch 135/200
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0011
# Epoch 136/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0012
# Epoch 137/200
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0010
# Epoch 138/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0012
# Epoch 139/200
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0011
# Epoch 140/200
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0011
# Epoch 141/200
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0011
# Epoch 142/200
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0013
# Epoch 143/200
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0011
# Epoch 144/200
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 145/200
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0012
# Epoch 146/200
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0011
# Epoch 147/200
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0011
# Epoch 148/200
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0011
# Epoch 149/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0011
# Epoch 150/200
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0012
# Epoch 151/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0012
# Epoch 152/200
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0010
# Epoch 153/200
# 22/22 [==============================] - 1s 22ms/step - loss: 0.0013
# Epoch 154/200
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0012
# Epoch 155/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0011
# Epoch 156/200
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0012
# Epoch 157/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 158/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 159/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 160/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 161/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 162/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 163/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 164/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 165/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 166/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 167/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 168/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 169/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 170/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 171/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 172/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 173/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0011
# Epoch 174/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0011
# Epoch 175/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0012
# Epoch 176/200
# 22/22 [==============================] - 0s 20ms/step - loss: 9.4766e-04
# Epoch 177/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0011
# Epoch 178/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0012
# Epoch 179/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 180/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 181/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 182/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 183/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 184/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 185/200
# 22/22 [==============================] - 0s 14ms/step - loss: 9.0698e-04
# Epoch 186/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 187/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 188/200
# 22/22 [==============================] - 0s 13ms/step - loss: 9.9635e-04
# Epoch 189/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 190/200
# 22/22 [==============================] - 0s 14ms/step - loss: 9.9177e-04
# Epoch 191/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 192/200
# 22/22 [==============================] - 0s 13ms/step - loss: 9.8199e-04
# Epoch 193/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 194/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 195/200
# 22/22 [==============================] - 0s 13ms/step - loss: 9.9430e-04
# Epoch 196/200
# 22/22 [==============================] - 0s 14ms/step - loss: 9.9826e-04
# Epoch 197/200
# 22/22 [==============================] - 0s 14ms/step - loss: 8.9668e-04
# Epoch 198/200
# 22/22 [==============================] - 0s 14ms/step - loss: 9.7306e-04
# Epoch 199/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0010
# Epoch 200/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0010

# %% [markdown]
# ###Model LSTM

# %%
# Set random seed for consistency of training
np.random.seed(8)
rn.seed(8)
tf.random.set_seed(8)

# Build model - LSTM with 100 neurons and 5 hidden layers
model_lstm = Sequential()
model_lstm.add(LSTM(units = num_neurons, return_sequences = True, input_shape = (X_train.shape[1], 1), activation='tanh'))
model_lstm.add(Dropout(dropout_rate))
model_lstm.add(LSTM(units = num_neurons, return_sequences = True, activation='tanh'))
model_lstm.add(Dropout(dropout_rate))
model_lstm.add(LSTM(units = num_neurons, return_sequences = True, activation='tanh'))
model_lstm.add(Dropout(dropout_rate))
model_lstm.add(LSTM(units = num_neurons, activation='tanh'))
model_lstm.add(Dropout(dropout_rate))

# Adding the output layer
model_lstm.add(Dense(units = 1))

# Compiling the RNN with Adam optimizer and mean squared error as the loss function
opt = keras.optimizers.Adam(learning_rate)
model_lstm.compile(optimizer = opt, loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model_lstm.fit(X_train, y_train, epochs = num_epochs, batch_size = batch_size)
# Out:
# Epoch 1/200
# 22/22 [==============================] - 7s 19ms/step - loss: 0.0475
# Epoch 2/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0126
# Epoch 3/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0094
# Epoch 4/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0077
# Epoch 5/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0076
# Epoch 6/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0072
# Epoch 7/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0064
# Epoch 8/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0060
# Epoch 9/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0058
# Epoch 10/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0055
# Epoch 11/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0054
# Epoch 12/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0051
# Epoch 13/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0053
# Epoch 14/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0050
# Epoch 15/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0047
# Epoch 16/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0051
# Epoch 17/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0048
# Epoch 18/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0050
# Epoch 19/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0050
# Epoch 20/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0048
# Epoch 21/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0045
# Epoch 22/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0044
# Epoch 23/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0045
# Epoch 24/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0045
# Epoch 25/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0044
# Epoch 26/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0043
# Epoch 27/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0039
# Epoch 28/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042
# Epoch 29/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0046
# Epoch 30/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0044
# Epoch 31/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0045
# Epoch 32/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039
# Epoch 33/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 34/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0041
# Epoch 35/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0041
# Epoch 36/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039
# Epoch 37/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039
# Epoch 38/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038
# Epoch 39/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038
# Epoch 40/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0040
# Epoch 41/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0040
# Epoch 42/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0038
# Epoch 43/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0037
# Epoch 44/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0037
# Epoch 45/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0035
# Epoch 46/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0037
# Epoch 47/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0035
# Epoch 48/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0037
# Epoch 49/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0036
# Epoch 50/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0035
# Epoch 51/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034
# Epoch 52/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0035
# Epoch 53/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034
# Epoch 54/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0035
# Epoch 55/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0036
# Epoch 56/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0036
# Epoch 57/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0032
# Epoch 58/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0034
# Epoch 59/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0034
# Epoch 60/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0033
# Epoch 61/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0033
# Epoch 62/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034
# Epoch 63/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0031
# Epoch 64/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0029
# Epoch 65/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0031
# Epoch 66/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0031
# Epoch 67/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0028
# Epoch 68/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0028
# Epoch 69/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0028
# Epoch 70/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0029
# Epoch 71/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0028
# Epoch 72/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0029
# Epoch 73/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 74/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0029
# Epoch 75/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 76/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0029
# Epoch 77/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 78/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0027
# Epoch 79/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0029
# Epoch 80/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0026
# Epoch 81/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0027
# Epoch 82/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 83/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 84/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 85/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 86/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 87/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0025
# Epoch 88/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 89/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 90/200
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0025
# Epoch 91/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0022
# Epoch 92/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0023
# Epoch 93/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0023
# Epoch 94/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0024
# Epoch 95/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0023
# Epoch 96/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0023
# Epoch 97/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0020
# Epoch 98/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 99/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0022
# Epoch 100/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 101/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0021
# Epoch 102/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 103/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0021
# Epoch 104/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 105/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0024
# Epoch 106/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 107/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0020
# Epoch 108/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 109/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0021
# Epoch 110/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0021
# Epoch 111/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0019
# Epoch 112/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0020
# Epoch 113/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 114/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 115/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 116/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 117/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018
# Epoch 118/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0019
# Epoch 119/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0020
# Epoch 120/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 121/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 122/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 123/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0020
# Epoch 124/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0019
# Epoch 125/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0018
# Epoch 126/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0017
# Epoch 127/200
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0019
# Epoch 128/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0017
# Epoch 129/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 130/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0018
# Epoch 131/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0018
# Epoch 132/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0017
# Epoch 133/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0018
# Epoch 134/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019
# Epoch 135/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0018
# Epoch 136/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 137/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016
# Epoch 138/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0017
# Epoch 139/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0016
# Epoch 140/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0017
# Epoch 141/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0016
# Epoch 142/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 143/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 144/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 145/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 146/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0017
# Epoch 147/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 148/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 149/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 150/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 151/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 152/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 153/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 154/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 155/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 156/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 157/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0017
# Epoch 158/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0018
# Epoch 159/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0017
# Epoch 160/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0017
# Epoch 161/200
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0017
# Epoch 162/200
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0015
# Epoch 163/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 164/200
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0017
# Epoch 165/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017
# Epoch 166/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0014
# Epoch 167/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0015
# Epoch 168/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016
# Epoch 169/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 170/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 171/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 172/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0017
# Epoch 173/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0017
# Epoch 174/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 175/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 176/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017
# Epoch 177/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 178/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 179/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 180/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 181/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 182/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0016
# Epoch 183/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0017
# Epoch 184/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 185/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0015
# Epoch 186/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 187/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0016
# Epoch 188/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0016
# Epoch 189/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0016
# Epoch 190/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0015
# Epoch 191/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0015
# Epoch 192/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0014
# Epoch 193/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0015
# Epoch 194/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0015
# Epoch 195/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0015
# Epoch 196/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0015
# Epoch 197/200
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0014
# Epoch 198/200
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0015
# Epoch 199/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 200/200
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0015

# %% [markdown]
# ###Model SimpleRNN

# %%
# Set random seed for consistency of training
np.random.seed(8)
rn.seed(8)
tf.random.set_seed(8)

# Build model - SimpleRNN with 100 neurons and 5 hidden layers
model_rnn = Sequential()
model_rnn.add(SimpleRNN(units = num_neurons, return_sequences = True, input_shape = (X_train.shape[1], 1), activation='tanh'))
model_rnn.add(Dropout(dropout_rate))
model_rnn.add(SimpleRNN(units = num_neurons, return_sequences = True, activation='tanh'))
model_rnn.add(Dropout(dropout_rate))
model_rnn.add(SimpleRNN(units = num_neurons, return_sequences = True, activation='tanh'))
model_rnn.add(Dropout(dropout_rate))
model_rnn.add(SimpleRNN(units = num_neurons, activation='tanh'))
model_rnn.add(Dropout(dropout_rate))

# Adding the output layer
model_rnn.add(Dense(units = 1))

# Compiling the RNN with Adam optimizer and mean squared error as the loss function
opt = keras.optimizers.Adam(learning_rate)
model_rnn.compile(optimizer = opt, loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model_rnn.fit(X_train, y_train, epochs = num_epochs, batch_size = batch_size)
# Out:
# Epoch 1/200
# 22/22 [==============================] - 9s 240ms/step - loss: 0.3674
# Epoch 2/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.3109
# Epoch 3/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.2466
# Epoch 4/200
# 22/22 [==============================] - 5s 250ms/step - loss: 0.2340
# Epoch 5/200
# 22/22 [==============================] - 4s 187ms/step - loss: 0.2015
# Epoch 6/200
# 22/22 [==============================] - 4s 195ms/step - loss: 0.1859
# Epoch 7/200
# 22/22 [==============================] - 5s 233ms/step - loss: 0.1704
# Epoch 8/200
# 22/22 [==============================] - 4s 178ms/step - loss: 0.1651
# Epoch 9/200
# 22/22 [==============================] - 5s 234ms/step - loss: 0.1542
# Epoch 10/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.1352
# Epoch 11/200
# 22/22 [==============================] - 4s 186ms/step - loss: 0.1286
# Epoch 12/200
# 22/22 [==============================] - 5s 250ms/step - loss: 0.1293
# Epoch 13/200
# 22/22 [==============================] - 5s 235ms/step - loss: 0.1249
# Epoch 14/200
# 22/22 [==============================] - 5s 211ms/step - loss: 0.1072
# Epoch 15/200
# 22/22 [==============================] - 5s 202ms/step - loss: 0.1023
# Epoch 16/200
# 22/22 [==============================] - 4s 195ms/step - loss: 0.1020
# Epoch 17/200
# 22/22 [==============================] - 6s 278ms/step - loss: 0.0974
# Epoch 18/200
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0861
# Epoch 19/200
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0788
# Epoch 20/200
# 22/22 [==============================] - 5s 243ms/step - loss: 0.0796
# Epoch 21/200
# 22/22 [==============================] - 4s 178ms/step - loss: 0.0769
# Epoch 22/200
# 22/22 [==============================] - 4s 190ms/step - loss: 0.0693
# Epoch 23/200
# 22/22 [==============================] - 5s 222ms/step - loss: 0.0738
# Epoch 24/200
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0677
# Epoch 25/200
# 22/22 [==============================] - 5s 233ms/step - loss: 0.0681
# Epoch 26/200
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0657
# Epoch 27/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0603
# Epoch 28/200
# 22/22 [==============================] - 5s 240ms/step - loss: 0.0548
# Epoch 29/200
# 22/22 [==============================] - 4s 178ms/step - loss: 0.0590
# Epoch 30/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0598
# Epoch 31/200
# 22/22 [==============================] - 5s 240ms/step - loss: 0.0497
# Epoch 32/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0502
# Epoch 33/200
# 22/22 [==============================] - 4s 177ms/step - loss: 0.0472
# Epoch 34/200
# 22/22 [==============================] - 5s 242ms/step - loss: 0.0471
# Epoch 35/200
# 22/22 [==============================] - 4s 179ms/step - loss: 0.0464
# Epoch 36/200
# 22/22 [==============================] - 5s 207ms/step - loss: 0.0454
# Epoch 37/200
# 22/22 [==============================] - 5s 209ms/step - loss: 0.0455
# Epoch 38/200
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0445
# Epoch 39/200
# 22/22 [==============================] - 5s 245ms/step - loss: 0.0472
# Epoch 40/200
# 22/22 [==============================] - 4s 176ms/step - loss: 0.0452
# Epoch 41/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0375
# Epoch 42/200
# 22/22 [==============================] - 5s 244ms/step - loss: 0.0384
# Epoch 43/200
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0421
# Epoch 44/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0398
# Epoch 45/200
# 22/22 [==============================] - 5s 237ms/step - loss: 0.0359
# Epoch 46/200
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0377
# Epoch 47/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0314
# Epoch 48/200
# 22/22 [==============================] - 5s 230ms/step - loss: 0.0376
# Epoch 49/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0329
# Epoch 50/200
# 22/22 [==============================] - 5s 221ms/step - loss: 0.0320
# Epoch 51/200
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0325
# Epoch 52/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0309
# Epoch 53/200
# 22/22 [==============================] - 5s 242ms/step - loss: 0.0314
# Epoch 54/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0300
# Epoch 55/200
# 22/22 [==============================] - 4s 177ms/step - loss: 0.0300
# Epoch 56/200
# 22/22 [==============================] - 5s 233ms/step - loss: 0.0317
# Epoch 57/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0285
# Epoch 58/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0273
# Epoch 59/200
# 22/22 [==============================] - 5s 243ms/step - loss: 0.0271
# Epoch 60/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0256
# Epoch 61/200
# 22/22 [==============================] - 4s 202ms/step - loss: 0.0274
# Epoch 62/200
# 22/22 [==============================] - 5s 208ms/step - loss: 0.0250
# Epoch 63/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0251
# Epoch 64/200
# 22/22 [==============================] - 5s 234ms/step - loss: 0.0237
# Epoch 65/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0239
# Epoch 66/200
# 22/22 [==============================] - 4s 179ms/step - loss: 0.0218
# Epoch 67/200
# 22/22 [==============================] - 5s 240ms/step - loss: 0.0215
# Epoch 68/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0219
# Epoch 69/200
# 22/22 [==============================] - 4s 179ms/step - loss: 0.0229
# Epoch 70/200
# 22/22 [==============================] - 5s 243ms/step - loss: 0.0209
# Epoch 71/200
# 22/22 [==============================] - 4s 179ms/step - loss: 0.0206
# Epoch 72/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0209
# Epoch 73/200
# 22/22 [==============================] - 5s 245ms/step - loss: 0.0206
# Epoch 74/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0211
# Epoch 75/200
# 22/22 [==============================] - 5s 228ms/step - loss: 0.0198
# Epoch 76/200
# 22/22 [==============================] - 6s 250ms/step - loss: 0.0216
# Epoch 77/200
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0192
# Epoch 78/200
# 22/22 [==============================] - 5s 247ms/step - loss: 0.0192
# Epoch 79/200
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0181
# Epoch 80/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0183
# Epoch 81/200
# 22/22 [==============================] - 7s 305ms/step - loss: 0.0184
# Epoch 82/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0165
# Epoch 83/200
# 22/22 [==============================] - 5s 233ms/step - loss: 0.0176
# Epoch 84/200
# 22/22 [==============================] - 8s 358ms/step - loss: 0.0155
# Epoch 85/200
# 22/22 [==============================] - 5s 236ms/step - loss: 0.0162
# Epoch 86/200
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0174
# Epoch 87/200
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0164
# Epoch 88/200
# 22/22 [==============================] - 5s 246ms/step - loss: 0.0171
# Epoch 89/200
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0152
# Epoch 90/200
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0147
# Epoch 91/200
# 22/22 [==============================] - 5s 246ms/step - loss: 0.0147
# Epoch 92/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0139
# Epoch 93/200
# 22/22 [==============================] - 5s 206ms/step - loss: 0.0144
# Epoch 94/200
# 22/22 [==============================] - 5s 201ms/step - loss: 0.0146
# Epoch 95/200
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0155
# Epoch 96/200
# 22/22 [==============================] - 5s 241ms/step - loss: 0.0149
# Epoch 97/200
# 22/22 [==============================] - 4s 177ms/step - loss: 0.0139
# Epoch 98/200
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0138
# Epoch 99/200
# 22/22 [==============================] - 5s 235ms/step - loss: 0.0144
# Epoch 100/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0133
# Epoch 101/200
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0131
# Epoch 102/200
# 22/22 [==============================] - 5s 240ms/step - loss: 0.0127
# Epoch 103/200
# 22/22 [==============================] - 4s 191ms/step - loss: 0.0122
# Epoch 104/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0120
# Epoch 105/200
# 22/22 [==============================] - 5s 231ms/step - loss: 0.0125
# Epoch 106/200
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0121
# Epoch 107/200
# 22/22 [==============================] - 5s 235ms/step - loss: 0.0122
# Epoch 108/200
# 22/22 [==============================] - 4s 178ms/step - loss: 0.0115
# Epoch 109/200
# 22/22 [==============================] - 4s 177ms/step - loss: 0.0123
# Epoch 110/200
# 22/22 [==============================] - 5s 237ms/step - loss: 0.0116
# Epoch 111/200
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0110
# Epoch 112/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0108
# Epoch 113/200
# 22/22 [==============================] - 5s 248ms/step - loss: 0.0102
# Epoch 114/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0106
# Epoch 115/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0113
# Epoch 116/200
# 22/22 [==============================] - 5s 245ms/step - loss: 0.0104
# Epoch 117/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0101
# Epoch 118/200
# 22/22 [==============================] - 4s 192ms/step - loss: 0.0100
# Epoch 119/200
# 22/22 [==============================] - 5s 221ms/step - loss: 0.0104
# Epoch 120/200
# 22/22 [==============================] - 4s 177ms/step - loss: 0.0108
# Epoch 121/200
# 22/22 [==============================] - 5s 247ms/step - loss: 0.0091
# Epoch 122/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0089
# Epoch 123/200
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0088
# Epoch 124/200
# 22/22 [==============================] - 5s 246ms/step - loss: 0.0090
# Epoch 125/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0088
# Epoch 126/200
# 22/22 [==============================] - 4s 179ms/step - loss: 0.0099
# Epoch 127/200
# 22/22 [==============================] - 5s 238ms/step - loss: 0.0100
# Epoch 128/200
# 22/22 [==============================] - 4s 179ms/step - loss: 0.0093
# Epoch 129/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0086
# Epoch 130/200
# 22/22 [==============================] - 5s 237ms/step - loss: 0.0088
# Epoch 131/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0097
# Epoch 132/200
# 22/22 [==============================] - 5s 226ms/step - loss: 0.0091
# Epoch 133/200
# 22/22 [==============================] - 5s 197ms/step - loss: 0.0083
# Epoch 134/200
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0082
# Epoch 135/200
# 22/22 [==============================] - 5s 244ms/step - loss: 0.0078
# Epoch 136/200
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0083
# Epoch 137/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0076
# Epoch 138/200
# 22/22 [==============================] - 5s 242ms/step - loss: 0.0079
# Epoch 139/200
# 22/22 [==============================] - 5s 242ms/step - loss: 0.0079
# Epoch 140/200
# 22/22 [==============================] - 5s 244ms/step - loss: 0.0072
# Epoch 141/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0072
# Epoch 142/200
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0076
# Epoch 143/200
# 22/22 [==============================] - 6s 297ms/step - loss: 0.0072
# Epoch 144/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0072
# Epoch 145/200
# 22/22 [==============================] - 4s 204ms/step - loss: 0.0077
# Epoch 146/200
# 22/22 [==============================] - 5s 223ms/step - loss: 0.0072
# Epoch 147/200
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0065
# Epoch 148/200
# 22/22 [==============================] - 5s 241ms/step - loss: 0.0069
# Epoch 149/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0073
# Epoch 150/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0076
# Epoch 151/200
# 22/22 [==============================] - 5s 244ms/step - loss: 0.0063
# Epoch 152/200
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0067
# Epoch 153/200
# 22/22 [==============================] - 4s 178ms/step - loss: 0.0060
# Epoch 154/200
# 22/22 [==============================] - 5s 243ms/step - loss: 0.0066
# Epoch 155/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0062
# Epoch 156/200
# 22/22 [==============================] - 4s 191ms/step - loss: 0.0065
# Epoch 157/200
# 22/22 [==============================] - 5s 222ms/step - loss: 0.0070
# Epoch 158/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0069
# Epoch 159/200
# 22/22 [==============================] - 5s 243ms/step - loss: 0.0061
# Epoch 160/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0067
# Epoch 161/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0059
# Epoch 162/200
# 22/22 [==============================] - 5s 239ms/step - loss: 0.0062
# Epoch 163/200
# 22/22 [==============================] - 4s 179ms/step - loss: 0.0062
# Epoch 164/200
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0060
# Epoch 165/200
# 22/22 [==============================] - 5s 248ms/step - loss: 0.0061
# Epoch 166/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0057
# Epoch 167/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0058
# Epoch 168/200
# 22/22 [==============================] - 5s 233ms/step - loss: 0.0059
# Epoch 169/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0062
# Epoch 170/200
# 22/22 [==============================] - 5s 214ms/step - loss: 0.0059
# Epoch 171/200
# 22/22 [==============================] - 5s 202ms/step - loss: 0.0065
# Epoch 172/200
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0059
# Epoch 173/200
# 22/22 [==============================] - 5s 241ms/step - loss: 0.0056
# Epoch 174/200
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0053
# Epoch 175/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0053
# Epoch 176/200
# 22/22 [==============================] - 5s 242ms/step - loss: 0.0046
# Epoch 177/200
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0059
# Epoch 178/200
# 22/22 [==============================] - 4s 178ms/step - loss: 0.0055
# Epoch 179/200
# 22/22 [==============================] - 5s 241ms/step - loss: 0.0052
# Epoch 180/200
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0052
# Epoch 181/200
# 22/22 [==============================] - 4s 196ms/step - loss: 0.0047
# Epoch 182/200
# 22/22 [==============================] - 5s 222ms/step - loss: 0.0050
# Epoch 183/200
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0052
# Epoch 184/200
# 22/22 [==============================] - 5s 239ms/step - loss: 0.0051
# Epoch 185/200
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0049
# Epoch 186/200
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0046
# Epoch 187/200
# 22/22 [==============================] - 5s 240ms/step - loss: 0.0049
# Epoch 188/200
# 22/22 [==============================] - 4s 179ms/step - loss: 0.0046
# Epoch 189/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0048
# Epoch 190/200
# 22/22 [==============================] - 5s 242ms/step - loss: 0.0047
# Epoch 191/200
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0047
# Epoch 192/200
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0043
# Epoch 193/200
# 22/22 [==============================] - 5s 226ms/step - loss: 0.0047
# Epoch 194/200
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0045
# Epoch 195/200
# 22/22 [==============================] - 5s 236ms/step - loss: 0.0042
# Epoch 196/200
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0044
# Epoch 197/200
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0045
# Epoch 198/200
# 22/22 [==============================] - 5s 237ms/step - loss: 0.0043
# Epoch 199/200
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0043
# Epoch 200/200
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0040

# %% [markdown]
# ## 7. Make Predictions using the test set

# %%
# We want predictions to contain same values as y_test data set
predictions_gru = model_gru.predict(X_test)
predictions_gru = scaler.inverse_transform(predictions_gru)
print("Prediction Shape", predictions_gru.shape)
# Out:
# 12/12 [==============================] - 1s 12ms/step
# Prediction Shape (366, 1)

# %%
# We want predictions to contain same values as y_test data set
predictions_lstm = model_lstm.predict(X_test)
predictions_lstm = scaler.inverse_transform(predictions_lstm)
print("Prediction Shape", predictions_lstm.shape)
# Out:
# 12/12 [==============================] - 2s 9ms/step
# Prediction Shape (366, 1)

# %%
# We want predictions to contain same values as y_test data set
predictions_rnn = model_rnn.predict(X_test)
predictions_rnn = scaler.inverse_transform(predictions_rnn)
print("Prediction Shape", predictions_rnn.shape)
# Out:
# 12/12 [==============================] - 1s 21ms/step
# Prediction Shape (366, 1)

# %% [markdown]
# ##8. Calculate the RMSE using the actual values
# RMSE is the standard deviation of the residuals and is a good measure of how accurately the model predicts the reponse. Lower values of RMSE indicate a better fit.

# %%
rmse_gru = np.sqrt(np.mean((predictions_gru - y_test)**2))
mape_gru = np.mean(np.abs((y_test - predictions_gru) / y_test)) * 100

print("RMSE:", rmse_gru)
print("MAPE:", mape_gru)
# Out:
# RMSE: 0.02555444193037666
# MAPE: 2.795544005099844

# %%
rmse_lstm = np.sqrt(np.mean((predictions_lstm - y_test)**2))
mape_lstm = np.mean(np.abs((y_test - predictions_lstm) / y_test)) * 100

print("RMSE:", rmse_lstm)
print("MAPE:", mape_lstm)
# Out:
# RMSE: 0.03633122224871046
# MAPE: 5.203605989395946

# %%
rmse_rnn = np.sqrt(np.mean((predictions_rnn - y_test)**2))
mape_rnn = np.mean(np.abs((y_test - predictions_rnn) / y_test)) * 100

print("RMSE:", rmse_rnn)
print("MAPE:", mape_rnn)
# Out:
# RMSE: 0.03232869778514475
# MAPE: 4.104122176228234

# %%
gru_pred = predictions_gru

# %%
lstm_pred = predictions_lstm

# %%
simplernn = predictions_rnn

# %% [markdown]
# 9. ## DataFrame of actual vs predicted prices

# %%
# Plot predicted vs actual values
#train =stock_kode_adj[:training_data_len]
test = stock_kode_adj[training_data_len:]
test['Predictions_SimpleRNN'] = simplernn
test['Predictions_LSTM'] = lstm_pred
test['Predictions_GRU'] = gru_pred

plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
#plt.plot(train['Adj Close'], label='Training')
plt.plot(test['Adj Close'], label='Actual')
plt.plot(test['Predictions_SimpleRNN'], label='SimpleRNN')
plt.plot(test['Predictions_LSTM'], label='LSTM')
plt.plot(test['Predictions_GRU'], label='GRU')
plt.title(stock_kode +" Close Price Actual vs Predicted", color = 'black', fontsize = 20)
plt.xlabel('Year', color = 'black', fontsize = 15)
plt.ylabel('Price', color = 'black', fontsize = 15)
plt.legend();
plt.savefig(stock_kode +"_ActualvsPredict.png")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots with shared x-axis
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8), sharex=True)
sns.set_style("whitegrid")

# Plot actual training data on the main chart
ax1.plot(stock_kode_adj.index[:training_data_len], stock_kode_adj['Adj Close'][:training_data_len], label='Training', linestyle='-', color='blue', alpha=0.7)

# Plot actual test data on the main chart
ax1.plot(test.index, test['Adj Close'], label='Actual', linestyle='-', color='green')

# Plot predictions on the main chart
ax1.plot(test.index, test['Predictions_SimpleRNN'], label='SimpleRNN', linestyle='--', color='red')
ax1.plot(test.index, test['Predictions_LSTM'], label='LSTM', linestyle='--', color='purple')
ax1.plot(test.index, test['Predictions_GRU'], label='GRU', linestyle='--', color='orange')

# Set title and labels for the main chart
ax1.set_title(stock_kode + " Close Price", color='black', fontsize=20)
ax1.set_ylabel('Price', color='black', fontsize=15)

# Add legend to the main chart
ax1.legend()

# Plot predictions zoomed in on the second chart
ax2.plot(test.index, test['Adj Close'], label='Actual', linestyle='-', color='green')
ax2.plot(test.index, test['Predictions_SimpleRNN'], label='SimpleRNN', linestyle='--', color='red')
ax2.plot(test.index, test['Predictions_LSTM'], label='LSTM', linestyle='--', color='purple')
ax2.plot(test.index, test['Predictions_GRU'], label='GRU', linestyle='--', color='orange')

# Set labels for the second chart
ax2.set_xlabel('Year', color='black', fontsize=15)
ax2.set_ylabel('Price', color='black', fontsize=15)

# Zoom in on the x-axis for the second chart
ax2.set_xlim([test.index[0], test.index[-1]])

# Add legend to the second chart
ax2.legend()

# Save the plot
plt.savefig("BNB-GRU.png")

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Plot predicted vs actual values
# train = stock_kode_adj[:training_data_len]
test = stock_kode_adj[training_data_len:]
test['Predictions_SimpleRNN'] = simplernn
test['Predictions_LSTM'] = lstm_pred
test['Predictions_GRU'] = gru_pred

plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")

# Plot actual values in blue
plt.plot(test.index, test['Adj Close'], label='Actual', color='blue', linestyle='-', marker='o', markersize=5)

# Plot SimpleRNN predictions in green
plt.plot(test.index, test['Predictions_SimpleRNN'], label='SimpleRNN', color='green', linestyle='--', marker='o', markersize=5)

# Plot LSTM predictions in red
plt.plot(test.index, test['Predictions_LSTM'], label='LSTM', color='red', linestyle='-.', marker='o', markersize=5)

# Plot GRU predictions in purple
plt.plot(test.index, test['Predictions_GRU'], label='GRU', color='purple', linestyle=':', marker='o', markersize=5)

plt.title(stock_kode + " Close Price", color='black', fontsize=20)
plt.xlabel('Year', color='black', fontsize=15)
plt.ylabel('Price', color='black', fontsize=15)
plt.legend()
plt.savefig("BNB-GRU.png")
plt.show()

# %%
# Plot predicted vs actual values
#train =stock_kode_adj[:training_data_len]
test = stock_kode_adj[training_data_len:]
test['Predictions'] = predictions_gru

plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
#plt.plot(train['Adj Close'], label='Training')
plt.plot(test['Adj Close'], label='Actual')
plt.plot(test['Predictions'], label='Predicted')
plt.title(stock_kode +" Close Price", color = 'black', fontsize = 20)
plt.xlabel('Year', color = 'black', fontsize = 15)
plt.ylabel('Price', color = 'black', fontsize = 15)
plt.legend();
plt.savefig("BNB-GRU.png")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you already have 'test' DataFrame with 'Adj Close' and 'Predictions' columns

plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")

plt.plot(test['Adj Close'], label='Actual')
plt.plot(test['Predictions'], label='Predicted')
plt.title(stock_kode + " Close Price", fontsize=20)
plt.xlabel('Year', fontsize=20)  # Increase the fontsize here
plt.ylabel('Price', fontsize=20)  # Increase the fontsize here
plt.legend()

plt.savefig("BNB-GRU.png")
plt.show()  # Add this line to display the plot

# %%
# Predicting 30 days into the future, using past 60 from the train data
future_days = 30
inputs = stock_kode_adj_arr[len(stock_kode_adj_arr) - 60:]
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_future = []
for i in range(future_days, len(inputs)):
    X_future.append(inputs[i-future_days:i, 0])

X_future = np.array(X_future)
X_future = np.reshape(X_future, (X_future.shape[0], X_future.shape[1], 1))

predicted_price = model_gru.predict(X_future)
predicted_price = scaler.inverse_transform(predicted_price)


# Plot the predicted price
plt.plot(predicted_price)
plt.title(f"Predicted price for the next {future_days} days")
plt.xlabel("Days")
plt.ylabel("Price ($)")
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
# Menampilkan 7 data teratas hasil prediksi
top_7_predicted = predicted_price[:7]
print(top_7_predicted)
# Out:
# [[0.49225548]
#  [0.48854244]
#  [0.47739768]
#  [0.47088137]
#  [0.470234  ]
#  [0.47079548]
#  [0.47529155]]

# %%
# Plot the predicted price
plt.plot(top_7_predicted)
plt.title(f"Predicted price for the next 7 days")
plt.xlabel("Days")
plt.ylabel("Price ($)")
plt.show()

# %%
 # Predicting 60 days into the future, using past 60 from the train data
future_days = 30
inputs = stock_kode_adj_arr[len(stock_kode_adj_arr) - 60:]
inputs = inputs.reshape(-1, 1)
inputs = scaler.transform(inputs)

X_future = []
for i in range(future_days, len(inputs)):
  X_future.append(inputs[i - future_days:i, 0])

X_future = np.array(X_future)
X_future = np.reshape(X_future, (X_future.shape[0], X_future.shape[1], 1))

predicted_price = model_gru.predict(X_future)
predicted_price = scaler.inverse_transform(predicted_price)

# Print the predicted prices and dates
last_date = df['Date'].iloc[-1]


dates = pd.date_range(start=last_date, periods=future_days+1, freq='D')[1:]
for date, price in zip(dates, predicted_price):
    print(f"Predicted price for {date.date()} is {price[0]:.2f} $")
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Predicted price for 2023-08-04 is 0.49 $
# Predicted price for 2023-08-05 is 0.49 $
# Predicted price for 2023-08-06 is 0.48 $
# Predicted price for 2023-08-07 is 0.47 $
# Predicted price for 2023-08-08 is 0.47 $
# Predicted price for 2023-08-09 is 0.47 $
# Predicted price for 2023-08-10 is 0.48 $
# Predicted price for 2023-08-11 is 0.48 $
# Predicted price for 2023-08-12 is 0.48 $
# Predicted price for 2023-08-13 is 0.64 $
# Predicted price for 2023-08-14 is 0.74 $
# Predicted price for 2023-08-15 is 0.75 $
# Predicted price for 2023-08-16 is 0.75 $
# Predicted price for 2023-08-17 is 0.75 $
# Predicted price for 2023-08-18 is 0.77 $
# Predicted price for 2023-08-19 is 0.80 $
# Predicted price for 2023-08-20 is 0.81 $
# Predicted price for 2023-08-21 is 0.79 $
# Predicted price for 2023-08-22 is 0.76 $
# Predicted price for 2023-08-23 is 0.74 $
# Predicted price for 2023-08-24 is 0.72 $
# Predicted price for 2023-08-25 is 0.71 $
# Predicted price for 2023-08-26 is 0.71 $
# Predicted price for 2023-08-27 is 0.72 $
# Predicted price for 2023-08-28 is 0.72 $
# Predicted price for 2023-08-29 is 0.72 $
# Predicted price for 2023-08-30 is 0.72 $
# Predicted price for 2023-08-31 is 0.71 $
# Predicted price for 2023-09-01 is 0.71 $
# Predicted price for 2023-09-02 is 0.70 $

# %%
predicted_price
# Out:
# array([[0.49225548],
#        [0.48854244],
#        [0.47739768],
#        [0.47088137],
#        [0.470234  ],
#        [0.47079548],
#        [0.47529155],
#        [0.47854114],
#        [0.4775953 ],
#        [0.6385412 ],
#        [0.7383196 ],
#        [0.75272447],
#        [0.75394607],
#        [0.7495582 ],
#        [0.766076  ],
#        [0.8027575 ],
#        [0.8112855 ],
#        [0.7944891 ],
#        [0.7597268 ],
#        [0.7411762 ],
#        [0.71976197],
#        [0.71110374],
#        [0.7148481 ],
#        [0.71939826],
#        [0.72104746],
#        [0.72113806],
#        [0.71692157],
#        [0.7100095 ],
#        [0.71020174],
#        [0.70158213]], dtype=float32)
